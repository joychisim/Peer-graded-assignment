# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Oparaocha Joy Chisimdindu**
# Data Scientist

# %% [markdown]
# *I am interested in data science because i want to change the world positively*

# %% [markdown]
# ### input: x=2; y=5
# x+y=7
#
# output: True

# %%
x=2
y=5
x+y
# Out:
# 7

# %% [markdown]
# `Domestic animals`
# > Dog
# Cat
# `Chiclken`
# ~~Goat~~
